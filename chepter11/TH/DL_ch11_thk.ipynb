# %% [markdown]
# ---
#
# <br>
#
# # KBRI DeepLearning Study 11장
#
# <br>
#
# * Hands-On Machine Learning with Scikit-Learn and TensorFlow by Aurélien Géron
# * 2부. 신경망과 딥러닝 - 11장. 심층 신경망 훈련하기
# * 신경망 잘 훈련하기
#
# <br>
#
# * gradient
#     * 초기화 -> 최근엔 HE, 르쿤.
#     * 활성함수
#     * BN
#     * gradient clipping
# * 재훈련
# * Optimizer
# * 규제, overfitting 방지 방법
#
# <br>

# %% [markdown]
# <br>
#
# * 가상환경 활성화 및 라이브러리 설치
#
#         # 가상환경 생성
#         conda create -n [ENV_NAME] python=3.8
#
#         # 가상환경 리스트 확인
#         conda env list
#
#         # 가상환경 내 패키지 확인
#         conda list -n [ENV_NAME]
#
#         # 가상환경 활성화 & 비활성화
#         conda activate th_kbri
#         conda deactivate th_kbri
#
#         # library 설치
#         conda install numpy
#         conda install pandas
#         conda install matplotlib
#         conda install seaborn
#         conda install scipy
#         conda install scikit-learn
#         conda install tensorflow
#         pip install pydot
#         pip install graphviz
#
# <br>

# %%
# 파이썬 ≥3.5 필수
import sys
assert sys.version_info >= (3, 5)

# 사이킷런 ≥0.20 필수
import sklearn
assert sklearn.__version__ >= "0.20"
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# 텐서플로 ≥2.0 필수
import tensorflow as tf
assert tf.__version__ >= "2.0"
from tensorflow.keras.utils import plot_model

# 공통 모듈 임포트
import numpy as np
import os

# 노트북 실행 결과를 동일하게 유지하기 위해
np.random.seed(42)

import pandas as pd

# 깔끔한 그래프 출력을 위해
import seaborn as sns
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# <br>
#
# ## 11장. 심층 신경망 훈련하기
#
# <br>

# %% [markdown]
# # <br>
#
# ### Vanishing Gradient & Exploding Gradient
#
# <br>

# %% [markdown]
# <br>
#
# * **Vanishing Gradient (그레이디언트 소실)**
#     * 러닝 알고리즘이 하위층으로 진행될수록 gradient가 점점 작아지는 경우
#     * 경사 하강법(gradient desent)이 하위층의 연결 가중치를 변경시키지 못하게 된다.
#
# <br>
#
# * **Exploding Gradient (그레이디언트 폭주)**
#     * 러닝 알고리즘이 하위층으로 진행될수록 gradient가 점점 커지는 경우
#     * 경사 하강법(gradient desent)이 비정상적으로 큰 가중치로 갱신을 시킨다.
#
# <br>
#
# * Logistic Sigmoid Activation Function(평균이 0.5)과 normal distribution(평균 0, 표준편차 1)을 통한 가중치 초기화 방법에 의해 Gradient가 불안정해질 수 있음.
#
#
# * 신경망에서 층이 진행될수록 분산이 커지게 되어 뒤 층에서 활성화 함수가 0이나 1로 수렴하게된다.
#
#
# * Logistic Sigmoid 함수의 특성상 입력이 0, 1로 수렴하게 되면 기울기가 0에 가까워진다. (아래 그림 참조)
#
# <br>

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))
    
def relu(z):
    return np.maximum(0, z)
    
def sign(z):
    return np.sign(z)

def tanh(z):
    return np.tanh(z)

def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, sign(z), "r-", linewidth=2, label="Step")
plt.plot(z, sigmoid(z), "g-", linewidth=2, label="Sigmoid")
plt.plot(z, tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-", linewidth=2, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("Activation functions", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r--", linewidth=2, label="Step")
plt.plot(z, derivative(sigmoid, z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, derivative(np.tanh, z), "b--", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=1, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("Derivatives", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])

plt.show()

# %% [markdown]
# <br>
#
# #### 불안정한 Gradient에 대한 초기화 방법 (Glorot, LuCun, He Initialization)
#
# <br>

# %% [markdown]
# <br>
#
# * 불안정한 gradient를 방지하기 위해서는 각 층의 입력의 분산과 출력의 분산이 동일해야하며 그레이디언트의 분산이 동일해야한다.
#
#
# * 한 층의 입력 개수(fan-in, 팬-인), 출력 개수(fan-out, 팬-아웃)이 같으면 위 두 가지가 가능할 수 있다. (층의 입력 개수 및 출력 개수 이므로, 층마다 값이 달라진다.)
#
#
# * 또는 대안적으로, 각 층의 연결 가중치 초기화 방법을 보완할 수 있다. 이 방법으로 Glorot, LuCun, He 초기화 방법 등이 있다.
#
#
#
# * 다양한 초기화 방법 코드에는 이 링크 (https://keras.io/ko/initializers/) 를 참조한다.
#
# <br>

# %% [markdown]
# <br>
#
# ##### Glorot Initialization 또는 Xavier Initialization
#
# <br>
#
# * 활성화 함수가 없거나, 하이퍼볼릭 탄젠트(tanh, hyperbolic tangent), 로지스틱(Logistic Sigmoid), 소프트맥스(SoftMax) 함수 등에는,
#
#
# * $fan_{avg} = \frac{(fan_{in}+fan_{out})}{2} $ 일 때,
#
#
# * 평균이 0, 분산이 $\sigma^{2} = \frac{1}{fan_{out}}$ 인 정규 분포 (normal dist)
#
#
# * $r = \sqrt{\frac{3}{fan_{avg}}}$ 일때, $-r$과 $+r$ 사이의 균등 분포 (uniform dist)
#
# <br>

# %% [markdown]
# <br>
#
# ##### Lucun Initialization
#
# <br>
#
# * SELU 활성화 함수에는,
#
#
#
# * 평균이 0, 분산이 $\sigma^{2} = \frac{1}{fan_{out}}$ 인 정규 분포 (normal dist)
#
#
# * $r = \sqrt{\frac{3}{fan_{in}}}$ 일때, $-r$과 $+r$ 사이의 균등 분포 (uniform dist)
#
# <br>

# %% [markdown]
# <br>
#
# ##### HE Initialization
#
# <br>
#
# * ReLu, ELU 등의 활성화 함수에는,
#
#
# * 평균이 0, 분산이 $\sigma^{2} = \frac{2}{fan_{in}}$ 인 정규 분포 (normal dist)
#
#
# * $r = \sqrt{3\sigma^{2}}$ 일때, $-r$과 $+r$ 사이의 균등 분포 (uniform dist)
#
# <br>
#
#         # Keras 층을 만들 때, 다음과 같이 초기화 방법에 넣을 수 있음.
#         keras.layers.Dense(10, activation="relu",
#                            kernel_initializer="he_normal") # "he_uniform"
#
#         # 만약 fan-out 기반의 균등분포 HE 초기화를 사용하고자 한다면,
#         he_avg_init = keras.initializers.VarianceScaling(scale=2.,
#                             mode="fan_avg", distribution="uniform")
#         keras.layers.Dense(10, activation="sigmoid",
#                            kernel_initializer="he_avg_init")
#
#
#
# <br>

# %% [markdown]
# <br>
#
# #### 수렴하지 않는 활성화 함수
#
#
# <br>

# %% [markdown]
# <br>
#
# * 활성화 함수에는 Step, Sign, Logistic Sigmoid, Tahn, ReLU, Softmax 등 다양한 것이 있다.
#
#
# * 최근 가장 좋은 것으로 알려져있는 것은 ReLu이다. 그러나 ReLu도 훈련 중 일부 뉴런이 0 이외의 값을 출력하지 않는 문제가 발생할 수 있다. (dying ReLU)
#
#
# * 입력의 가중치 합이 음수가 되면 ReLU 함수의 gradient가 0이 되기 때문이다.
#
#
# * 대안적으로 LeakyReLu 같은 변종 ReLU 함수를 사용할 수 있다.
#
# <br>

# %% [markdown]
# 옵티마이저
# 1) SGD
# 2) Momentum
# 3) NAG
# 4) ADAGRAD
# 5) ADam
# 등...
#
# 요새는... ADAM = ADAGRAD
#  NADAM
#  웬만하면 ADAM

# %% [markdown]
# <br>
#
# ### Optimizer, Activation, Initializer를 조합하여 모델을 만들고 평가하기
#
# <br>
#
# * 수렴이 언제부터 시작되나요?
#
# * 모델의 성능은 어떤가요?
#
# * 전체 훈련 속도는 몇인가요?
#
# <br>

# %% [markdown]
# ----
# #### [ 0 ]
#
# <br>
#
# * CIFAR10 데이터셋을 불러오세요. keras.datasets.cifar10.load_ data()를 사용하여 데이터를 적재할 수 있습니다.
# * 데이터셋의 차원을 확인해봅시다.
# * Dense layer을 사용하기 때문에 데이터의 shape을 1차원으로 바꿔야 합니다. ( np.reshape(데이터, (바꿀shape) ) 사용)
#
# <br>

# %%
# cifar dataset 불러오기
# 아래의 코드를 통해 train set, test set이 분리되어 들어간다.
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
# reshape
# x_train = np.reshape(x_train, 
#                      (50000, 32*32*3))
x_train = np.reshape(x_train, 
                     (x_train.shape[0], x_train.shape[1]*x_train.shape[2]*x_train.shape[3]))
x_test = np.reshape(x_test, 
                    (x_test.shape[0], x_test.shape[1]*x_test.shape[2]*x_test.shape[3]))

# %%
# normalization
# asix 0 -> 한 obsevation에서가 아닌 각 feature들에서 normalization을 해야하는 것이므로 
# axis는 0으로. https://www.sharpsightlabs.com/blog/numpy-mean/참조 
# keepdims=True -> input의 dimension과 output의 dimension이 동일하도록. 
pixel_means = x_train.mean(axis=0, keepdims=True)
pixel_stds = x_train.std(axis=0, keepdims=True)
x_train_scaled = (x_train - pixel_means) / pixel_stds
x_test_scaled = (x_test - pixel_means) / pixel_stds

# %%
x_test_scaled.shape
# Out:
# (10000, 3072)

# %% [markdown]
# ----
# #### [ 1 ]
#
# <br>
#
# * **100**개의 뉴런을 가진 **은닉층** **20개**를 쌓아 심층 신경망을 만듭니다.
# * 모든 은닉층의 initializer는 **He 초기화**를, 활성화 함수는 **Relu** 함수를 사용합니다.
# * 출력층은 **10개**의 뉴런과 **소프트맥스 활성화** 함수를 사용합니다.
# * 출력층에서는 Initializer를 사용하지 않습니다.
#
# <br>

# %% [markdown]
# * HE 초기화: ReLu, ELU 등의 활성화 함수에 사용
# * 평균이 0, 분산이 $\sigma^{2} = \frac{2}{fan_{in}}$ 인 정규 분포 (normal dist)

# %%
# 모델 구조 정의
def make_model_1():
    model = tf.keras.models.Sequential() # Sequential 모델
    model.add(tf.keras.layers.InputLayer((32*32*3))) # Input layer

    for _ in range(20): # dense layer. 총 20개
        model.add(tf.keras.layers.Dense(100, activation="relu", 
                                        kernel_initializer='he_normal'))  
        # kernel initializer는 he_normal
        
    model.add(tf.keras.layers.Dense(10, activation="softmax"))
    # cifar는 10개 범주에 대한 단일 integer class로 결과값이 구분되므로 
    # 출력층의 activation은 softmax
    return model

# %% [markdown]
# ----
# ##### 1-1 )
#
# <br>
#
# * 옵티마이저는 **Adam**를 사용합니다.
# * 모델 저장 이름은 **1-1_model.h5** 로 합니다.
#
# <br>

# %%
#모델 생성
model=make_model_1()
model.summary()
plot_model(model)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_63 (Dense)             (None, 100)               307300
# _________________________________________________________________
# dense_64 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_65 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_66 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_67 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_68 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_69 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_70 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_71 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_72 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_73 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_74 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_75 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_76 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_77 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_78 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_79 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_80 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_81 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_82 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_83 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 500,210
# Trainable params: 500,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일
model.compile(loss="sparse_categorical_crossentropy", 
              # label이 one-hot encoding이 아닌 단일 integer로 나올때 space_categorical_crossentropy 사용
              # label이 one-hot encoding이면 categorical_crossentropy 사용
              optimizer=tf.keras.optimizers.Adam(),
              # Optimizer는 SGD가 아닌 Adam 사용
              # Adam parameter는 Adam(beta_1=0.9, beta_2=0.999)이 좋다고 함.
              metrics=["accuracy"])

# 콜백 선언
  # best model만 저장하는 callback
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("1-1_model.h5", 
                                                         save_best_only=True)
  # 훈련이 효과가 없으면 early stopping하는 callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

  # tensorboard 사용을 위한 callback
tensorboard_cb = tf.keras.callbacks.TensorBoard('logs')

# %%
# 훈련 전 모델 평가
model_test = model.evaluate(x_test_scaled, y_test)
print(model_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.8588 - accuracy: 0.0997
# [2.8588240146636963, 0.09969999641180038]

# %%
# 훈련 전 모델 예측
y_pred = model.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

plt.figure(figsize=(15,3))
plt.plot(y_test[:100], marker='o')
plt.plot(y_pred_class[:100], marker='o')
plt.legend(('y true', 'y pred'))

# %%
g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1000
#            1       0.00      0.00      0.00      1000
#            2       0.00      0.00      0.00      1000
#            3       0.00      0.00      0.00      1000
#            4       0.10      1.00      0.18      1000
#            5       0.00      0.00      0.00      1000
#            6       0.00      0.00      0.00      1000
#            7       0.00      0.00      0.00      1000
#            8       0.00      0.00      0.00      1000
#            9       0.00      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.01      0.10      0.02     10000
# weighted avg       0.01      0.10      0.02     10000

# %%
# 모델 훈련
model.fit(x_train_scaled, y_train, 
          validation_split=0.2,
          epochs=20,
          callbacks=[model_checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/20
#    1/1250 [..............................] - ETA: 0s - loss: 2.5572 - accuracy: 0.2188WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\th_kbri\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1250 [..............................] - ETA: 1:32 - loss: 2.6706 - accuracy: 0.1562WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_train_batch_end` time: 0.1376s). Check your callbacks.
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.9867 - accuracy: 0.2463 - val_loss: 1.8597 - val_accuracy: 0.3022
# Epoch 2/20
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.8163 - accuracy: 0.3138 - val_loss: 1.7846 - val_accuracy: 0.3216
# Epoch 3/20
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.7371 - accuracy: 0.3520 - val_loss: 1.7574 - val_accuracy: 0.3613
# Epoch 4/20
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.6846 - accuracy: 0.3848 - val_loss: 1.6888 - val_accuracy: 0.3867
# Epoch 5/20
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.6257 - accuracy: 0.4111 - val_loss: 1.6730 - val_accuracy: 0.4132
# Epoch 6/20
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.5849 - accuracy: 0.4273 - val_loss: 1.6676 - val_accuracy: 0.4004
# Epoch 7/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5441 - accuracy: 0.4439 - val_loss: 1.6197 - val_accuracy: 0.4148
# Epoch 8/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.5280 - accuracy: 0.4502 - val_loss: 1.6086 - val_accuracy: 0.4339
# Epoch 9/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.4954 - accuracy: 0.4650 - val_loss: 1.6291 - val_accuracy: 0.4080
# Epoch 10/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.4817 - accuracy: 0.4682 - val_loss: 1.5519 - val_accuracy: 0.4499
# Epoch 11/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.4393 - accuracy: 0.4832 - val_loss: 1.5892 - val_accuracy: 0.4349
# Epoch 12/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4193 - accuracy: 0.4916 - val_loss: 1.5906 - val_accuracy: 0.4361
# Epoch 13/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3991 - accuracy: 0.5010 - val_loss: 1.5620 - val_accuracy: 0.4538
# Epoch 14/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3648 - accuracy: 0.5180 - val_loss: 1.5387 - val_accuracy: 0.4671
# Epoch 15/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3381 - accuracy: 0.5276 - val_loss: 1.5615 - val_accuracy: 0.4544
# Epoch 16/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3315 - accuracy: 0.5304 - val_loss: 1.5633 - val_accuracy: 0.4720
# Epoch 17/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3032 - accuracy: 0.5379 - val_loss: 1.5288 - val_accuracy: 0.4639
# Epoch 18/20
# 1250/1250 [==============================] - 11s 8ms/step - loss: 1.2806 - accuracy: 0.5457 - val_loss: 1.5857 - val_accuracy: 0.4584
# Epoch 19/20
# 1250/1250 [==============================] - 11s 8ms/step - loss: 1.2730 - accuracy: 0.5497 - val_loss: 1.5153 - val_accuracy: 0.4732
# Epoch 20/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2392 - accuracy: 0.5638 - val_loss: 1.5325 - val_accuracy: 0.4715

# %%
# 훈련 후 모델 평가
model1_1 = tf.keras.models.load_model('1-1_model.h5')
model_test = model1_1.evaluate(x_test_scaled, y_test)
print(model_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4949 - accuracy: 0.1086
# [1.494940996170044, 0.10859999805688858]

# %%
y_pred = model1_1.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.58      0.55      1000
#            1       0.55      0.68      0.61      1000
#            2       0.37      0.26      0.31      1000
#            3       0.28      0.48      0.35      1000
#            4       0.38      0.45      0.41      1000
#            5       0.59      0.20      0.30      1000
#            6       0.44      0.59      0.50      1000
#            7       0.70      0.44      0.54      1000
#            8       0.70      0.59      0.64      1000
#            9       0.56      0.54      0.55      1000
#
#     accuracy                           0.48     10000
#    macro avg       0.51      0.48      0.48     10000
# weighted avg       0.51      0.48      0.48     10000

# %% [markdown]
# ----
# ##### 1-2 )
#
# <br>
#
# * 옵티마이저는 **Adam**을 사용합니다. Adam의 파라미터 **beta1**, **beta2**를 0.9, 0.999로 초기화 합니다.
# * 콜백 ModelCheckpoint의 저장 이름을 **1-2_model.h5**로 바꿉니다.
#
# <br>

# %%
#모델 생성
model1=make_model_1()

# 모델 컴파일
model1.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(beta_1=0.9, beta_2=0.999),
              metrics=["accuracy"]) 

# 콜백 선언
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("1-2_model.h5", 
                                                         save_best_only=True)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)
tensorboard_cb = tf.keras.callbacks.TensorBoard('logs')

# 모델 훈련
model1.fit(x_train_scaled, y_train,
          validation_split=0.2,
          epochs=20,
          callbacks=[model_checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/20
#    2/1250 [..............................] - ETA: 30:03 - loss: 2.8022 - accuracy: 0.0781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 2.8766s). Check your callbacks.
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.9882 - accuracy: 0.2445 - val_loss: 1.8913 - val_accuracy: 0.2884
# Epoch 2/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.8146 - accuracy: 0.3173 - val_loss: 1.7744 - val_accuracy: 0.3290
# Epoch 3/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.7582 - accuracy: 0.3486 - val_loss: 1.7430 - val_accuracy: 0.3526
# Epoch 4/20
# 1250/1250 [==============================] - 12s 9ms/step - loss: 1.7098 - accuracy: 0.3692 - val_loss: 1.7653 - val_accuracy: 0.3547
# Epoch 5/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6609 - accuracy: 0.3829 - val_loss: 1.7504 - val_accuracy: 0.3647
# Epoch 6/20
# 1250/1250 [==============================] - 9s 8ms/step - loss: 1.6365 - accuracy: 0.3997 - val_loss: 1.6787 - val_accuracy: 0.3877
# Epoch 7/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6048 - accuracy: 0.4173 - val_loss: 1.6381 - val_accuracy: 0.4069
# Epoch 8/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5857 - accuracy: 0.4233 - val_loss: 1.6467 - val_accuracy: 0.4091
# Epoch 9/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5559 - accuracy: 0.4396 - val_loss: 1.6760 - val_accuracy: 0.4116
# Epoch 10/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5351 - accuracy: 0.4435 - val_loss: 1.6329 - val_accuracy: 0.4156
# Epoch 11/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5227 - accuracy: 0.4583 - val_loss: 1.6024 - val_accuracy: 0.4295
# Epoch 12/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4909 - accuracy: 0.4652 - val_loss: 1.5977 - val_accuracy: 0.4358
# Epoch 13/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4759 - accuracy: 0.4715 - val_loss: 1.6099 - val_accuracy: 0.4295
# Epoch 14/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4618 - accuracy: 0.4814 - val_loss: 1.6306 - val_accuracy: 0.4333
# Epoch 15/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4593 - accuracy: 0.4839 - val_loss: 1.5819 - val_accuracy: 0.4499
# Epoch 16/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4307 - accuracy: 0.4945 - val_loss: 1.6039 - val_accuracy: 0.4357
# Epoch 17/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4505 - accuracy: 0.4859 - val_loss: 1.6033 - val_accuracy: 0.4299
# Epoch 18/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4189 - accuracy: 0.4965 - val_loss: 1.6264 - val_accuracy: 0.4414
# Epoch 19/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4083 - accuracy: 0.5034 - val_loss: 1.5604 - val_accuracy: 0.4560
# Epoch 20/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3954 - accuracy: 0.5074 - val_loss: 1.6245 - val_accuracy: 0.4448

# %%
# 훈련 후 모델 평가
model1_2 = tf.keras.models.load_model('1-2_model.h5')
model_test = model1_2.evaluate(x_test_scaled, y_test)
print(model_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5365 - accuracy: 0.1265
# [1.53654944896698, 0.1264999955892563]

# %%
y_pred = model1_2.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.56      0.49      1000
#            1       0.62      0.55      0.59      1000
#            2       0.32      0.23      0.27      1000
#            3       0.29      0.34      0.31      1000
#            4       0.38      0.35      0.36      1000
#            5       0.36      0.36      0.36      1000
#            6       0.47      0.48      0.48      1000
#            7       0.57      0.52      0.55      1000
#            8       0.61      0.68      0.64      1000
#            9       0.54      0.51      0.52      1000
#
#     accuracy                           0.46     10000
#    macro avg       0.46      0.46      0.46     10000
# weighted avg       0.46      0.46      0.46     10000

# %% [markdown]
# ----
# #### [ 2 ]
#
# <br>
#
# * **100**개의 뉴런을 가진 **은닉층** **20개**를 쌓아 심층 신경망을 만듭니다.
# * 모든 은닉층의 initializer는 **He 초기화**를, 활성화 함수는 **Elu** 함수를 사용합니다.
# * 출력층은 **10개**의 뉴런과 **소프트맥스 활성화** 함수를 사용합니다.
# * 출력층에서는 **initializer**를 사용하지 않습니다.
#
# <br>

# %%
def make_model_2():
    model = tf.keras.models.Sequential() # Sequential 모델
    model.add(tf.keras.layers.InputLayer((32*32*3))) # Input layer

    for _ in range(20): # dense layer. 총 20개
        model.add(tf.keras.layers.Dense(100, activation="elu", 
                                        kernel_initializer='he_normal'))  
        
    model.add(tf.keras.layers.Dense(10, activation="softmax"))
    return model

# %% [markdown]
# <br>
#
# ##### 2-1 )
#
# <br>
#
# * 옵티마이저는 **Adam**을 사용합니다. Adam의 파라미터 **beta1**, **beta2**를 0.9, 0.999로 초기화 합니다.
# * 콜백 ModelCheckpoint의 저장 이름을 **2-1_model.h5**로 바꿉니다.
#
# <br>

# %%
model2 = make_model_2()

# 모델 컴파일
model2.compile(loss="sparse_categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Adam(beta_1=0.9, beta_2=0.999),
              metrics=["accuracy"])

# 콜백 선언
  # best model만 저장하는 callback
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("2-1_model.h5", 
                                                         save_best_only=True)
  # 훈련이 효과가 없으면 early stopping하는 callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

  # tensorboard 사용을 위한 callback
tensorboard_cb = tf.keras.callbacks.TensorBoard('logs')

# %%
# 모델 훈련
model2.fit(x_train_scaled, y_train, 
          validation_split=0.2,
          epochs=20,
          callbacks=[model_checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/20
#    2/1250 [..............................] - ETA: 30:15 - loss: 4.1550 - accuracy: 0.0625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0060s vs `on_train_batch_end` time: 2.8985s). Check your callbacks.
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.9725 - accuracy: 0.2908 - val_loss: 1.8222 - val_accuracy: 0.3403
# Epoch 2/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7414 - accuracy: 0.3719 - val_loss: 1.7589 - val_accuracy: 0.3601
# Epoch 3/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6628 - accuracy: 0.4017 - val_loss: 1.6857 - val_accuracy: 0.4184
# Epoch 4/20
# 1250/1250 [==============================] - 9s 8ms/step - loss: 1.6145 - accuracy: 0.4252 - val_loss: 1.7025 - val_accuracy: 0.3991
# Epoch 5/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5611 - accuracy: 0.4473 - val_loss: 1.6826 - val_accuracy: 0.4095
# Epoch 6/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.5274 - accuracy: 0.4598 - val_loss: 1.5965 - val_accuracy: 0.4457
# Epoch 7/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.4865 - accuracy: 0.4749 - val_loss: 1.5675 - val_accuracy: 0.4536
# Epoch 8/20
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.4476 - accuracy: 0.4919 - val_loss: 1.5840 - val_accuracy: 0.4503
# Epoch 9/20
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.4282 - accuracy: 0.4970 - val_loss: 1.5573 - val_accuracy: 0.4626
# Epoch 10/20
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.4385 - accuracy: 0.4985 - val_loss: 1.5772 - val_accuracy: 0.4541
# Epoch 11/20
# 1250/1250 [==============================] - 11s 9ms/step - loss: 1.3587 - accuracy: 0.5247 - val_loss: 1.5459 - val_accuracy: 0.4680
# Epoch 12/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3441 - accuracy: 0.5274 - val_loss: 1.5471 - val_accuracy: 0.4815
# Epoch 13/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3152 - accuracy: 0.5433 - val_loss: 1.5224 - val_accuracy: 0.4750
# Epoch 14/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2874 - accuracy: 0.5488 - val_loss: 1.5316 - val_accuracy: 0.4718
# Epoch 15/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2857 - accuracy: 0.5514 - val_loss: 1.5684 - val_accuracy: 0.4548
# Epoch 16/20
# 1250/1250 [==============================] - 11s 8ms/step - loss: 1.2828 - accuracy: 0.5552 - val_loss: 1.5491 - val_accuracy: 0.4838
# Epoch 17/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 30.1739 - accuracy: 0.4859 - val_loss: 1.7027 - val_accuracy: 0.3864
# Epoch 18/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4851 - accuracy: 0.4619 - val_loss: 1.6470 - val_accuracy: 0.4261
# Epoch 19/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4068 - accuracy: 0.5013 - val_loss: 1.5878 - val_accuracy: 0.4455
# Epoch 20/20
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3439 - accuracy: 0.5238 - val_loss: 1.5710 - val_accuracy: 0.4610

# %%
# 훈련 후 모델 평가 및 예측
model2_1 = tf.keras.models.load_model('2-1_model.h5')
model2_1.evaluate(x_test_scaled, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4905 - accuracy: 0.1031
# [1.490513801574707, 0.1031000018119812]

# %%
# 훈련 후 모델 예측
y_pred = model2_1.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

plt.figure(figsize=(15,3))
plt.plot(y_test[:100], marker='o')
plt.plot(y_pred_class[:100], marker='o')
plt.legend(('y true', 'y pred'))

# %%
g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.58      0.57      1000
#            1       0.63      0.53      0.57      1000
#            2       0.49      0.21      0.29      1000
#            3       0.33      0.18      0.23      1000
#            4       0.39      0.36      0.37      1000
#            5       0.36      0.54      0.43      1000
#            6       0.44      0.71      0.54      1000
#            7       0.55      0.57      0.56      1000
#            8       0.61      0.63      0.62      1000
#            9       0.53      0.58      0.56      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.49      0.49      0.48     10000
# weighted avg       0.49      0.49      0.48     10000

# %% [markdown]
# <br>
#
# ##### 2-2 )
#
# <br>
#
# * 옵티마이저는 **Nadam**을 사용합니다. Ndam의 학습률을 **5e-5** 로 초기화합니다
# * 콜백 ModelCheckpoint의 저장 이름을 **2-2_model.h5**로 바꿉니다.
#
# <br>

# %%
model3 = make_model_2()

# 모델 컴파일
model3.compile(loss="sparse_categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Nadam(lr=5e-5),
              metrics=["accuracy"])

# 콜백 선언
  # best model만 저장하는 callback
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("2-2_model.h5", 
                                                         save_best_only=True)
  # 훈련이 효과가 없으면 early stopping하는 callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

  # tensorboard 사용을 위한 callback
tensorboard_cb = tf.keras.callbacks.TensorBoard('logs')

# %%
# 모델 훈련
model3.fit(x_train_scaled, y_train, 
          validation_split=0.2,
          epochs=20,
          callbacks=[model_checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/20
#    2/1250 [..............................] - ETA: 56:31 - loss: 7.1818 - accuracy: 0.1094WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 5.4197s). Check your callbacks.
# 1250/1250 [==============================] - 21s 17ms/step - loss: 2.1517 - accuracy: 0.2500 - val_loss: 1.8866 - val_accuracy: 0.3217
# Epoch 2/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.7811 - accuracy: 0.3570 - val_loss: 1.7629 - val_accuracy: 0.3763
# Epoch 3/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.6576 - accuracy: 0.4073 - val_loss: 1.6918 - val_accuracy: 0.3957
# Epoch 4/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.5664 - accuracy: 0.4419 - val_loss: 1.6480 - val_accuracy: 0.4163
# Epoch 5/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.4922 - accuracy: 0.4654 - val_loss: 1.6087 - val_accuracy: 0.4296
# Epoch 6/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.4286 - accuracy: 0.4926 - val_loss: 1.5955 - val_accuracy: 0.4298
# Epoch 7/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.3741 - accuracy: 0.5140 - val_loss: 1.5956 - val_accuracy: 0.4400
# Epoch 8/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.3231 - accuracy: 0.5308 - val_loss: 1.5741 - val_accuracy: 0.4506
# Epoch 9/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.2736 - accuracy: 0.5479 - val_loss: 1.5963 - val_accuracy: 0.4463
# Epoch 10/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2277 - accuracy: 0.5663 - val_loss: 1.5869 - val_accuracy: 0.4524
# Epoch 11/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.1855 - accuracy: 0.5803 - val_loss: 1.6212 - val_accuracy: 0.4550
# Epoch 12/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1409 - accuracy: 0.5976 - val_loss: 1.6302 - val_accuracy: 0.4575
# Epoch 13/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.1018 - accuracy: 0.6107 - val_loss: 1.6620 - val_accuracy: 0.4547
# Epoch 14/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0666 - accuracy: 0.6223 - val_loss: 1.6798 - val_accuracy: 0.4575
# Epoch 15/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0300 - accuracy: 0.6360 - val_loss: 1.6981 - val_accuracy: 0.4605
# Epoch 16/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.9918 - accuracy: 0.6519 - val_loss: 1.7262 - val_accuracy: 0.4520
# Epoch 17/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 0.9554 - accuracy: 0.6644 - val_loss: 1.7848 - val_accuracy: 0.4381
# Epoch 18/20
# 1250/1250 [==============================] - 16s 12ms/step - loss: 0.9230 - accuracy: 0.6762 - val_loss: 1.8059 - val_accuracy: 0.4458

# %%
# 훈련 후 모델 평가 및 예측
model2_2 = tf.keras.models.load_model('2-2_model.h5')
model2_2.evaluate(x_test_scaled, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.5477 - accuracy: 0.0806
# [1.5476895570755005, 0.08060000091791153]

# %%
# 훈련 후 모델 예측
y_pred = model2_2.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

plt.figure(figsize=(15,3))
plt.plot(y_test[:100], marker='o')
plt.plot(y_pred_class[:100], marker='o')
plt.legend(('y true', 'y pred'))

# %%
g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.47      0.52      1000
#            1       0.55      0.59      0.57      1000
#            2       0.33      0.30      0.31      1000
#            3       0.30      0.29      0.30      1000
#            4       0.37      0.43      0.40      1000
#            5       0.39      0.31      0.35      1000
#            6       0.45      0.54      0.49      1000
#            7       0.52      0.47      0.49      1000
#            8       0.55      0.64      0.59      1000
#            9       0.50      0.52      0.51      1000
#
#     accuracy                           0.46     10000
#    macro avg       0.45      0.46      0.45     10000
# weighted avg       0.45      0.46      0.45     10000

# %% [markdown]
# ----
# #### [ 3 ]
#
# <br>
#
# * **100**개의 뉴런을 가진 **은닉층** **20개**를 쌓아 심층 신경망을 만듭니다.
# * 모든 은닉층의 initializer는 **He 초기화**를, 활성화 함수는 **Elu** 함수를 사용합니다.
# * 모든 은닉층의 다음층에서 BatchNormaliztion을 수행합니다.
# * 출력층은 **10개**의 뉴런과 **소프트맥스 활성화** 함수를 사용합니다.
# * 출력층에서는 **initializer**를 사용하지 않습니다.
# * 출력층 다음층에서는 BatchNormalization을 수행하지 않습니다.
#
# <br>

# %%
def make_model_3():
    model = tf.keras.models.Sequential() # Sequential 모델
    model.add(tf.keras.layers.InputLayer((32*32*3))) # Input layer

    for _ in range(20): # dense layer. 총 20개
        model.add(tf.keras.layers.Dense(100, activation="elu", 
                                        kernel_initializer='he_normal'))  
        model.add(tf.keras.layers.BatchNormalization())
        
    model.add(tf.keras.layers.Dense(10, activation="softmax"))
    return model

# %% [markdown]
# * 옵티마이저는 **Nadam**을 사용합니다. Ndam의 학습률을 **5e-5** 로 초기화합니다
# * 콜백 ModelCheckpoint의 저장 이름을 **3_model.h5**로 바꿉니다.

# %%
model4 = make_model_3()

# 모델 컴파일
model4.compile(loss="sparse_categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Nadam(lr=5e-5),
              metrics=["accuracy"])

# 콜백 선언
  # best model만 저장하는 callback
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("3_model.h5", 
                                                         save_best_only=True)
  # 훈련이 효과가 없으면 early stopping하는 callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

  # tensorboard 사용을 위한 callback
tensorboard_cb = tf.keras.callbacks.TensorBoard('logs')

# %%
# 모델 훈련
model4.fit(x_train_scaled, y_train, 
          validation_split=0.2,
          epochs=20,
          callbacks=[model_checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/20
#    2/1250 [..............................] - ETA: 1:44:03 - loss: 3.0746 - accuracy: 0.1406WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0179s vs `on_train_batch_end` time: 9.9825s). Check your callbacks.
# 1250/1250 [==============================] - 34s 27ms/step - loss: 2.3193 - accuracy: 0.2004 - val_loss: 1.9876 - val_accuracy: 0.2900
# Epoch 2/20
# 1250/1250 [==============================] - 23s 18ms/step - loss: 1.9368 - accuracy: 0.3062 - val_loss: 1.8228 - val_accuracy: 0.3522
# Epoch 3/20
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.8293 - accuracy: 0.3415 - val_loss: 1.7387 - val_accuracy: 0.3789
# Epoch 4/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.7602 - accuracy: 0.3715 - val_loss: 1.6794 - val_accuracy: 0.4046
# Epoch 5/20
# 1250/1250 [==============================] - 24s 20ms/step - loss: 1.7060 - accuracy: 0.3887 - val_loss: 1.6321 - val_accuracy: 0.4170
# Epoch 6/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.6627 - accuracy: 0.4049 - val_loss: 1.5970 - val_accuracy: 0.4317
# Epoch 7/20
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.6217 - accuracy: 0.4234 - val_loss: 1.5738 - val_accuracy: 0.4429
# Epoch 8/20
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.5895 - accuracy: 0.4356 - val_loss: 1.5516 - val_accuracy: 0.4452
# Epoch 9/20
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.5517 - accuracy: 0.4480 - val_loss: 1.5467 - val_accuracy: 0.4531
# Epoch 10/20
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.5300 - accuracy: 0.4580 - val_loss: 1.5007 - val_accuracy: 0.4692
# Epoch 11/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.5085 - accuracy: 0.4651 - val_loss: 1.4896 - val_accuracy: 0.4703
# Epoch 12/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.4936 - accuracy: 0.4690 - val_loss: 1.4800 - val_accuracy: 0.4788
# Epoch 13/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.4695 - accuracy: 0.4782 - val_loss: 1.4698 - val_accuracy: 0.4786
# Epoch 14/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.4420 - accuracy: 0.4897 - val_loss: 1.4587 - val_accuracy: 0.4859
# Epoch 15/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.4295 - accuracy: 0.4934 - val_loss: 1.4624 - val_accuracy: 0.4816
# Epoch 16/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.4101 - accuracy: 0.4973 - val_loss: 1.4477 - val_accuracy: 0.4890
# Epoch 17/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.3966 - accuracy: 0.5054 - val_loss: 1.4485 - val_accuracy: 0.4890
# Epoch 18/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.3797 - accuracy: 0.5122 - val_loss: 1.4387 - val_accuracy: 0.4914
# Epoch 19/20
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.3594 - accuracy: 0.5158 - val_loss: 1.4255 - val_accuracy: 0.4983
# Epoch 20/20
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.3485 - accuracy: 0.5221 - val_loss: 1.4421 - val_accuracy: 0.4947

# %%
# 훈련 후 모델 평가 및 예측
model3_0 = tf.keras.models.load_model('3_model.h5')
model3_0.evaluate(x_test_scaled, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4240 - accuracy: 0.0882
# [1.42400062084198, 0.08820000290870667]

# %%
# 훈련 후 모델 예측
y_pred = model3_0.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

plt.figure(figsize=(15,3))
plt.plot(y_test[:100], marker='o')
plt.plot(y_pred_class[:100], marker='o')
plt.legend(('y true', 'y pred'))

# %%
g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.52      0.55      1000
#            1       0.59      0.61      0.60      1000
#            2       0.40      0.37      0.38      1000
#            3       0.35      0.33      0.34      1000
#            4       0.43      0.41      0.42      1000
#            5       0.44      0.37      0.40      1000
#            6       0.47      0.61      0.53      1000
#            7       0.58      0.55      0.57      1000
#            8       0.59      0.67      0.63      1000
#            9       0.52      0.54      0.53      1000
#
#     accuracy                           0.50     10000
#    macro avg       0.50      0.50      0.49     10000
# weighted avg       0.50      0.50      0.49     10000

# %% [markdown]
# ----
# #### [ 4 ]
#
# <br>
#
# * **100**개의 뉴런을 가진 **은닉층** **20개**를 쌓아 심층 신경망을 만듭니다.
# * 모든 은닉층의 initializer는 **르쿤 초기화**를, 활성화 함수는 **Selu** 함수를 사용합니다.
# * 출력층은 **10개**의 뉴런과 **소프트맥스 활성화** 함수를 사용합니다.
# * 출력층에서는 **initializer**를 사용하지 않습니다.
#
# <br>
# * **Selu**의 장점은 self-normalization. 각 층의 출력이 평균 0, 표준편차 1을 유지하기 때문에 vanishing gradient나 exploding gradient 문제를 피할 수 있음.
# * **Selu** 사용 시 주의 사항
#     * 모든 입력 feature는 평균 0, 표준펴차 1로 표준화되어야 함.
#     * 모든 은닉층의 가중치는 lecun 정규 분포로 초기화되어야 함.
#     * 네트워크는 일렬로 쌓은 층으로 구성되어야 함. 순환 신경망이나 skip connection (wide & deep model)과 같은 순차적이지 않은 구조에 Selu를 사용하면 자기 정규화되는 것을 보장하지 않음.

# %%
def make_model_4():
    model = tf.keras.models.Sequential() # Sequential 모델
    model.add(tf.keras.layers.InputLayer((32*32*3))) # Input layer

    for _ in range(20): # dense layer. 총 20개
        model.add(tf.keras.layers.Dense(100, activation="selu", 
                                        kernel_initializer='lecun_normal'))  
        # model.add(tf.keras.layers.BatchNormalization())
        
    model.add(tf.keras.layers.Dense(10, activation="softmax"))    
    return model

# %% [markdown]
# * 옵티마이저는 **Nadam**을 사용합니다. Ndam의 학습률을 **5e-5** 로 초기화합니다
# * 콜백 ModelCheckpoint의 저장 이름을 **4_model.h5**로 바꿉니다.

# %%
model5 = make_model_4()

# 모델 컴파일
model5.compile(loss="sparse_categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Nadam(lr=5e-5),
              metrics=["accuracy"])

# 콜백 선언
  # best model만 저장하는 callback
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("4_model.h5", 
                                                         save_best_only=True)
  # 훈련이 효과가 없으면 early stopping하는 callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

  # tensorboard 사용을 위한 callback
tensorboard_cb = tf.keras.callbacks.TensorBoard('logs')

# %%
# 모델 훈련
model5.fit(x_train_scaled, y_train, 
          validation_split=0.2,
          epochs=20,
          callbacks=[model_checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/20
#    2/1250 [..............................] - ETA: 1:27:30 - loss: 3.3424 - accuracy: 0.0781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0133s vs `on_train_batch_end` time: 8.3970s). Check your callbacks.
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.8883 - accuracy: 0.3266 - val_loss: 1.7556 - val_accuracy: 0.3683
# Epoch 2/20
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.6571 - accuracy: 0.4068 - val_loss: 1.6453 - val_accuracy: 0.4106
# Epoch 3/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.5544 - accuracy: 0.4456 - val_loss: 1.6042 - val_accuracy: 0.4294
# Epoch 4/20
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.4801 - accuracy: 0.4723 - val_loss: 1.5537 - val_accuracy: 0.4488
# Epoch 5/20
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.4184 - accuracy: 0.4964 - val_loss: 1.5412 - val_accuracy: 0.4535
# Epoch 6/20
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3662 - accuracy: 0.5127 - val_loss: 1.5409 - val_accuracy: 0.4576
# Epoch 7/20
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.3182 - accuracy: 0.5316 - val_loss: 1.5149 - val_accuracy: 0.4677
# Epoch 8/20
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.2716 - accuracy: 0.5491 - val_loss: 1.5114 - val_accuracy: 0.4746
# Epoch 9/20
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.2334 - accuracy: 0.5599 - val_loss: 1.5072 - val_accuracy: 0.4736
# Epoch 10/20
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.1918 - accuracy: 0.5778 - val_loss: 1.5263 - val_accuracy: 0.4772
# Epoch 11/20
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.1590 - accuracy: 0.5865 - val_loss: 1.5183 - val_accuracy: 0.4766
# Epoch 12/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.1216 - accuracy: 0.6021 - val_loss: 1.5431 - val_accuracy: 0.4859
# Epoch 13/20
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.0910 - accuracy: 0.6127 - val_loss: 1.5476 - val_accuracy: 0.4828
# Epoch 14/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0565 - accuracy: 0.6245 - val_loss: 1.5649 - val_accuracy: 0.4794
# Epoch 15/20
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.0268 - accuracy: 0.6369 - val_loss: 1.5684 - val_accuracy: 0.4824
# Epoch 16/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 0.9964 - accuracy: 0.6486 - val_loss: 1.5850 - val_accuracy: 0.4853
# Epoch 17/20
# 1250/1250 [==============================] - 20s 16ms/step - loss: 0.9641 - accuracy: 0.6614 - val_loss: 1.5968 - val_accuracy: 0.4895
# Epoch 18/20
# 1250/1250 [==============================] - 18s 14ms/step - loss: 0.9364 - accuracy: 0.6693 - val_loss: 1.6215 - val_accuracy: 0.4775
# Epoch 19/20
# 1250/1250 [==============================] - 18s 14ms/step - loss: 0.9091 - accuracy: 0.6804 - val_loss: 1.6346 - val_accuracy: 0.4843

# %%
# 훈련 후 모델 평가 및 예측
model4_0 = tf.keras.models.load_model('4_model.h5')
model4_0.evaluate(x_test_scaled, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4961 - accuracy: 0.1016
# [1.496057391166687, 0.10159999877214432]

# %%
# 훈련 후 모델 예측
y_pred = model4_0.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

plt.figure(figsize=(15,3))
plt.plot(y_test[:100], marker='o')
plt.plot(y_pred_class[:100], marker='o')
plt.legend(('y true', 'y pred'))

# %%
g = sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f')
g.set_ylabel('Actual label');
g.set_xlabel('Predicted label');

# %%
print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.54      0.54      1000
#            1       0.55      0.65      0.59      1000
#            2       0.37      0.37      0.37      1000
#            3       0.32      0.36      0.34      1000
#            4       0.44      0.34      0.39      1000
#            5       0.40      0.39      0.40      1000
#            6       0.52      0.52      0.52      1000
#            7       0.50      0.52      0.51      1000
#            8       0.59      0.58      0.59      1000
#            9       0.53      0.48      0.50      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.47     10000
# weighted avg       0.47      0.47      0.47     10000

# %% [markdown]
# ----
# #### [ 5 ]
#
# <br>
#
# * 지금까지 만든 6가지 모델을 불러오고 평가해 봅니다.
# * **tf.keras.models.load_model( )**을 통해 모델을 불러올 수 있습니다.
# * **model.evaluate( )**를 통해 모든 모델을 평가해 봅니다.
# * 불러오기 전에 아래 셀에서 각 모델의 특징을 간단히 메모하세요
#
# <br>

# %% [markdown]
# <br>
#
# * model_11: HE 초기화, Relu, Adam
# * model_12: HE 초기화, Relu, Adam(beta_1=0.9, beta_2=0.999)
# * model_21: HE 초기화, Elu, Adam(beta_1=0.9, beta_2=0.999)
# * model_22: HE 초기화, Elu, Nadam(lr = 5e-5)
# * model_3: HE 초기화, Elu, BatchNormalization, Nadam(lr = 5e-5)
# * model_4: Lecun 초기화, Selu, Nadam(lr = 5e-5
#
# <br>

# %%
# 모델 불러오기
model_11 = tf.keras.models.load_model('1-1_model.h5')
model_12 = tf.keras.models.load_model('1-2_model.h5')
model_21 = tf.keras.models.load_model('2-1_model.h5')
model_22 = tf.keras.models.load_model('2-2_model.h5')
model_3 = tf.keras.models.load_model('3_model.h5')
model_4 = tf.keras.models.load_model('4_model.h5')

# %%
# 모델 평가
m11_test = model_11.evaluate(x_test_scaled, y_test)
m12_test = model_12.evaluate(x_test_scaled, y_test)
m21_test = model_21.evaluate(x_test_scaled, y_test)
m22_test = model_22.evaluate(x_test_scaled, y_test)
m3_test = model_3.evaluate(x_test_scaled, y_test)
m4_test = model_4.evaluate(x_test_scaled, y_test)
print("m11:", m11_test, "\n",
      "m12:", m12_test, "\n",
      "m21:", m21_test, "\n",
      "m22:", m22_test, "\n",
      "m3:", m3_test, "\n",
      "m4L", m4_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4949 - accuracy: 0.1086
# 313/313 [==============================] - 1s 4ms/step - loss: 1.5365 - accuracy: 0.1265
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4905 - accuracy: 0.1031
# 313/313 [==============================] - 1s 4ms/step - loss: 1.5477 - accuracy: 0.0806
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4240 - accuracy: 0.0882
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4961 - accuracy: 0.1016
# m11: [1.494940996170044, 0.10859999805688858]
#  m12: [1.53654944896698, 0.1264999955892563]
#  m21: [1.490513801574707, 0.1031000018119812]
#  m22: [1.5476895570755005, 0.08060000091791153]
#  m3: [1.42400062084198, 0.08820000290870667]
#  m4L [1.496057391166687, 0.10159999877214432]

# %%
# 훈련 후 모델 예측
y_pred = model_12.predict(x_test_scaled)
y_pred_class = np.argmax(y_pred, axis=1)
y_pred_class = y_pred_class.tolist()

plt.figure(figsize=(15,3))
plt.plot(y_test[:100], marker='o')
plt.plot(y_pred_class[:100], marker='o')
plt.legend(('y true', 'y pred'))

# %%
fig, axes = plt.subplots(ncols=2)
fig.set_size_inches(15,5)
sns.heatmap(confusion_matrix(y_test,y_pred_class),annot=True,fmt='2.0f', ax=axes[0])
axes[0].set_ylabel('Actual label');
axes[0].set_xlabel('Predicted label');
sns.heatmap(confusion_matrix(y_test,y_pred_class)/1000*100,annot=True,fmt='2.0f', ax=axes[1])
axes[0].set_ylabel('Actual label');
axes[0].set_xlabel('Predicted label');
plt.tight_layout()

# %%
print(classification_report(y_test, y_pred_class))

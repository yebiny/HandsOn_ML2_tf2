# %% [markdown]
# # 0-Setting

# %%
import tensorflow as tf
import numpy as np


# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from tensorflow.keras import models, layers, optimizers, losses, metrics, activations

# %% [markdown]
# ----
# # 1. fMNIST 데이터 불러오기

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype(np.float32) / 255
x_test = x_test.astype(np.float32) / 255
x_train.shape, x_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ----
# # 2. 모델 Development

# %% [markdown]
# ## 17.3.1 적층 오토인코더

# %%
def build_stacked_ae():
    stacked_encoder = models.Sequential([
        layers.Flatten(input_shape=[28, 28]),
        layers.Dense(100, activation="selu"),
        layers.Dense(10, activation="selu"),
    ])
    stacked_decoder = models.Sequential([
        layers.Dense(100, activation="selu", input_shape=[10]),
        layers.Dense(28 * 28, activation="sigmoid"),
        layers.Reshape([28, 28])
    ])
    stacked_ae = models.Sequential([stacked_encoder, stacked_decoder])
    
    
    return stacked_ae, stacked_encoder

# %% [markdown]
# ## 17.3.5. 가중치 묶기

# %%
class DenseTranspose(layers.Layer):
    
    
    
    
    
    
    return self.activation(z + self.biases)


def build_tied_ae():
    
    
    
    
    
    
    
    return tied_ae

# %% [markdown]
# ## 17.4 합성곱 오토인코더

# %%
def build_conv_ae():


    
    
    
    
    
    
    
    return conv_ae

# %% [markdown]
# ## 17.5 순환 오토인코더

# %%
def build_recurrent_ae():

    
    
    
    
    
    
    
    
    
    
    return recurrent_ae

# %% [markdown]
# ## 17.6 잡음제거 오토인코더

# %%
def build_denoising_ae():

    
    
    
    
    
    
    
    
    
    
    
    return denoising_ae


def build_dropout_ae():
    
    
    
    
    
    
    
    
    
    
    
    return dropout_ae

# %% [markdown]
# ## 17.7 희소 오토인코더

# %%
def build_sparse_ae():


    
    
    
    
    
    
    return sparse_l1_ae

# %% [markdown]
# ----
# # 3. 모델 컴파일 & 훈련

# %%
def rounded_accuracy(y_true, y_pred):
    return metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
model, encoder = build_stacked_ae()
model.summary()
model.compile(loss="binary_crossentropy",
                optimizer=optimizers.SGD(lr=1.5), metrics=[rounded_accuracy])
history = model.fit(x_train, x_train, epochs=10,
                      validation_split=0.2)
# Out:
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_48 (Sequential)   (None, 10)                79510
# _________________________________________________________________
# sequential_49 (Sequential)   (None, 28, 28)            80284
# =================================================================
# Total params: 159,794
# Trainable params: 159,794
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.3589 - rounded_accuracy: 0.8687 - val_loss: 0.3291 - val_rounded_accuracy: 0.8963
# Epoch 2/10
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.3231 - rounded_accuracy: 0.8986 - val_loss: 0.3196 - val_rounded_accuracy: 0.9033
# Epoch 3/10
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.3179 - rounded_accuracy: 0.9027 - val_loss: 0.3200 - val_rounded_accuracy: 0.9034
# Epoch 4/10
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.3153 - rounded_accuracy: 0.9046 - val_loss: 0.3248 - val_rounded_accuracy: 0.8890
# Epoch 5/10
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.3138 - rounded_accuracy: 0.9057 - val_loss: 0.3135 - val_rounded_accuracy: 0.9072
# Epoch 6/10
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.3126 - rounded_accuracy: 0.9066 - val_loss: 0.3147 - val_rounded_accuracy: 0.9057
# Epoch 7/10
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.3112 - rounded_accuracy: 0.9078 - val_loss: 0.3123 - val_rounded_accuracy: 0.9090
# Epoch 8/10
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.3096 - rounded_accuracy: 0.9091 - val_loss: 0.3105 - val_rounded_accuracy: 0.9076
# Epoch 9/10
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.3081 - rounded_accuracy: 0.9104 - val_loss: 0.3355 - val_rounded_accuracy: 0.8938
# Epoch 10/10
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.3067 - rounded_accuracy: 0.9117 - val_loss: 0.3060 - val_rounded_accuracy: 0.9135

# %% [markdown]
# ----
# # 4. 모델 시각화

# %% [markdown]
# ## 17.3.2 재구성 시각화

# %%
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

def show_reconstructions(model, images, n_images=8):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
#dropout = layers.Dropout(0.5)
#noise = layers.GaussianNoise(0.2)

show_reconstructions(model, x_test)

# %% [markdown]
# ## 17.3.3 패션 MNIST 데이터셋 시각화

# %%
from sklearn.manifold import TSNE

def tsne_projection(encoder, x_data):
    x_data_compressed = encoder.predict(x_data)
    tsne = TSNE()
    out_tsne = tsne.fit_transform(x_data_compressed)
    
    return out_tsne

def plot_projection(out_tsne, label):
    x_2d = (out_tsne - out_tsne.min()) / (out_tsne.max() - out_tsne.min())
    plt.figure(figsize=(6,6))
    plt.scatter(x_2d[:, 0], x_2d[:, 1], c=label, s=10, cmap="tab10")
    plt.axis("off")
    plt.show()

def plot_fmnist(out_tsne, x_data, y_data):
    x_2d = (out_tsne - out_tsne.min()) / (out_tsne.max() - out_tsne.min())
    plt.figure(figsize=(10, 8))
    cmap = plt.cm.tab10
    plt.scatter(x_2d[:, 0], x_2d[:, 1], c=y_data, s=10, cmap=cmap)
    image_positions = np.array([[1., 1.]])
    for index, position in enumerate(x_2d):
        dist = np.sum((position - image_positions) ** 2, axis=1)
        if np.min(dist) > 0.02: # if far enough from other images
            image_positions = np.r_[image_positions, [position]]
            imagebox = mpl.offsetbox.AnnotationBbox(
                mpl.offsetbox.OffsetImage(x_data[index], cmap="binary"),
                position, bboxprops={"edgecolor": cmap(y_data[index]), "lw": 2})
            plt.gca().add_artist(imagebox)
    plt.axis("off")
    plt.show()

# %%
out_tsne = tsne_projection(encoder, x_test)
plot_projection(out_tsne, y_test)
plot_fmnist(out_tsne, x_test, y_test)

# %% [markdown]
# ----
# # 5. 뉴련 활성화 시각화

# %%
def plot_percent_hist(ax, data, bins):
    counts, _ = np.histogram(data, bins=bins)
    widths = bins[1:] - bins[:-1]
    x = bins[:-1] + widths / 2
    ax.bar(x, counts / len(data), width=widths*0.8)
    ax.xaxis.set_ticks(bins)
    ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(
        lambda y, position: "{}%".format(int(np.round(100 * y)))))
    ax.grid(True)
    
    
def plot_activations_histogram(encoder, x_data, height=1, n_bins=10):
    x_codings = encoder(x_data).numpy()
    activation_means = x_codings.mean(axis=0)
    mean = activation_means.mean()
    bins = np.linspace(0, 1, n_bins + 1)

    fig, [ax1, ax2] = plt.subplots(figsize=(10, 3), nrows=1, ncols=2, sharey=True)
    
    plot_percent_hist(ax1, x_codings.ravel(), bins)
    ax1.plot([mean, mean], [0, height], "k--", label="Overall Mean = {:.2f}".format(mean))
    ax1.legend(loc="upper center", fontsize=14)
    ax1.set_xlabel("Activation")
    ax1.set_ylabel("% Activations")
    ax1.axis([0, 1, 0, height])
    
    plot_percent_hist(ax2, activation_means, bins)
    ax2.plot([mean, mean], [0, height], "k--")
    ax2.set_xlabel("Neuron Mean Activation")
    ax2.set_ylabel("% Neurons")
    ax2.axis([0, 1, 0, height])

# %%
plot_activations_histogram(encoder, x_test, )
plt.show()
